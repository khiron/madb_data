# %%
import cogent3 

al = cogent3.load_aligned_seqs('../primates100/ENSG00000004455-0.fa',moltype="dna")
al = al.rename_seqs(lambda x: x.split(':')[0])
al = al.take_seqs(['homo_sapiens','pan_troglodytes','gorilla_gorilla','macaca_mulatta'])
al = al.omit_gap_pos()
al.set_repr_policy(ref_name='homo_sapiens')
al[1260:]
# Out:
# 4 x 88768 dna alignment: homo_sapiens[AGTGGTAAAA...], pan_troglodytes[AGTGGTAAAA...], gorilla_gorilla[AGTGGTAAAA...], ...
